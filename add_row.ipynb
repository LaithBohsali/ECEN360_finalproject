# %%
import csv
import time

# Define the file name
filename = 'Final_Data.csv'

import pandas as pd
df = pd.read_csv(filename)

# Function to add a row to the CSV
with open(filename, 'a', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
# Input data from the user
ind = 120
    while (True):
        year = input("Enter Year: ")
        position = input("Enter Position: ")
        team = input("Enter Team: ")
        points = input("Enter Points: ")
        xG = input("Enter xG: ")
        xGA = input("Enter xGA: ")
        xGD = xG - xGA
        xGD_per_90 = xGD/90
        average_market_value = input("Enter Average Market Value: ")
        total_market_value = input("Enter Total Market Value: ")
        normalized_market_value = input("Enter Normalized Market Value: ")
        
        csvwriter.writerow([ind, year, position, team, points, xG, xGA, xGD, xGD_per_90, average_market_value, total_market_value, normalized_market_value])
        ind += 1
# Out:
# Enter Year:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      13 # Input data from the user
#      14     while (True):
# ---> 15         year = input("Enter Year: ")
#      16         position = input("Enter Position: ")
#      17         team = input("Enter Team: ")
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
# ...
