# %% [markdown]
# # Final Project - Premier League Prediction Model
# ---
# **DATA**
# - _FINANCIAL DATA:_ BigPositionVsValue.csv
#
# Derived From: Abhi webscraped it from transfermarkt.com.
# Webscraping file(https://colab.research.google.com/drive/1srVYYCftf7WLi4HWeOgCKn-eq9KE4hIT?usp=sharing).
#
# Important Features: Team's Total Financial Data.
# Will need to apply a data transformation to the data to ensure every team's market value is between 0 and 1.
#
#
# - _MATCH DATA:_ MatchData.csv
#
# Derived From: https://fbref.com/en/comps/9/2017-2018/2017-2018-Premier-League-Stats
#
# Important Features: xGD.
#
# ---
# **Instructions on How to Run**
#
# 1) Locate Model.ipynb and run each box from top to bottom.
# 2) To view other files, nothing should change
# If any errors are encountered, try to change the file path for the data as per your local files.
# ---
